# %%
## AADTokenCredentials for multi-factor authentication
from msrestazure.azure_active_directory import AADTokenCredentials

## Required for Azure Data Lake Analytics job management
from azure.mgmt.datalake.analytics.job import DataLakeAnalyticsJobManagementClient
from azure.mgmt.datalake.analytics.job.models import JobInformation, JobState, USqlJobProperties

## Other required imports
import adal, uuid, time

def authenticate_device_code():
    """
    Authenticate the end-user using device auth.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    tenant = '<TENANT_ID_OR_DOMAIN>'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    client_id = '04b07795-8ddb-461a-bbee-02f9e1bf7b46'

    context = adal.AuthenticationContext(authority_uri, api_version=None)
    code = context.acquire_user_code(resource_uri, client_id)
    print(code['message'])
    mgmt_token = context.acquire_token_with_device_code(resource_uri, code, client_id)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

def authenticate_username_password():
    """
    Authenticate using user w/ username + password.
    This doesn't work for users or tenants that have multi-factor authentication required.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    tenant = '<TENANT>'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    username = '<USERNAME>'
    password = '<PASSWORD>'
    client_id = '<CLIENT_ID>'

    context = adal.AuthenticationContext(authority_uri, api_version=None)
    mgmt_token = context.acquire_token_with_username_password(resource_uri, username, password, client_id)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

def authenticate_client_key():
    """
    Authenticate using service principal w/ key.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    tenant = '<TENANT>'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    client_id = '<CLIENT_ID>'
    client_secret = '<CLIENT_SECRET>'

    context = adal.AuthenticationContext(authority_uri, api_version=None)
    mgmt_token = context.acquire_token_with_client_credentials(resource_uri, client_id, client_secret)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

def authenticate_client_cert():
    """
    Authenticate using service principal w/ cert.
    """
    authority_host_uri = 'https://login.microsoftonline.com'
    tenant = '<TENANT>'
    authority_uri = authority_host_uri + '/' + tenant
    resource_uri = 'https://management.core.windows.net/'
    client_id = '<CLIENT_ID>'
    client_cert = '<CLIENT_CERT>'
    client_cert_thumbprint = '<CLIENT_CERT_THUMBPRINT>'

    context = adal.AuthenticationContext(authority_uri, api_version=None)

    mgmt_token = context.acquire_token_with_client_certificate(resource_uri, client_id, client_cert, client_cert_thumbprint)
    credentials = AADTokenCredentials(mgmt_token, client_id)

    return credentials

if __name__ == '__main__':
    creds = authenticate_device_code()

    adla_account = '<ADLA_ACCOUNT_NAME>'
    resource_group = '<RESOURCE_GROUP_NAME>'
    sub_id = '<SUBSCRIPTION-ID>'

    job_client = DataLakeAnalyticsJobManagementClient(creds, 'azuredatalakeanalytics.net')

    script = '@a = SELECT * FROM (VALUES ("Hello, World!")) AS T(message); OUTPUT @a TO "/Samples/Output/HelloWorld.csv" USING Outputters.Csv();'

    job_id = str(uuid.uuid4())

    job_client.job.create(adla_account, job_id, JobInformation(
        name='HelloWorld',
        type='USql',
        properties=USqlJobProperties(script=script)
    ))

    job_result = job_client.job.get(adla_account, job_id)

    while job_result.state != JobState.ended:
        print('Job is not yet done. Waiting for 3 seconds. Current state: ' + job_result.state.value)
        time.sleep(3)
        job_result = job_client.job.get(adla_account, job_id)    

    print('Job finished with result: ' + job_result.result.value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-81b007041ab1> in <module>
#       1 ## AADTokenCredentials for multi-factor authentication
# ----> 2 from msrestazure.azure_active_directory import AADTokenCredentials
#       3
#       4 ## Required for Azure Data Lake Analytics job management
#       5 from azure.mgmt.datalake.analytics.job import DataLakeAnalyticsJobManagementClient
#
# ModuleNotFoundError: No module named 'msrestazure'

# %%
from azure.storage.blob import BlockBlobService
from azure.storage.blob import ContentSettings

block_blob_service = BlockBlobService(account_name='hackathoninnoai', account_key='IrZ5NR+e/OX4FcHLet9bUdurOX6O6lmRHJRfLn3x4e+hbKQ0tjoCMVi0OxiwHnnzY092cqofXfx4A48AeKfWLw==')
block_blob_service.create_container('static')

#Upload the CSV file to Azure cloud
block_blob_service.create_blob_from_path(
    'static',
    'statistics_app/pictures/radar_test_1aaa.png',
    'radar_test_1.png',
    content_settings=ContentSettings(content_type='application/octetstream')
            )

# Check the list of blob
generator = block_blob_service.list_blobs('static')
for blob in generator:
    print(blob.name)
# Out:
# Bootstrap/css/bootstrap-grid.css
# Bootstrap/css/bootstrap-grid.css.map
# Bootstrap/css/bootstrap-grid.min.css
# Bootstrap/css/bootstrap-grid.min.css.map
# Bootstrap/css/bootstrap-reboot.css
# Bootstrap/css/bootstrap-reboot.css.map
# Bootstrap/css/bootstrap-reboot.min.css
# Bootstrap/css/bootstrap-reboot.min.css.map
# Bootstrap/css/bootstrap.css
# Bootstrap/css/bootstrap.css.map
# Bootstrap/css/bootstrap.min.css
# Bootstrap/css/bootstrap.min.css.map
# Bootstrap/js/bootstrap.bundle.js
# Bootstrap/js/bootstrap.bundle.js.map
# Bootstrap/js/bootstrap.bundle.min.js
# Bootstrap/js/bootstrap.bundle.min.js.map
# Bootstrap/js/bootstrap.js
# Bootstrap/js/bootstrap.js.map
# Bootstrap/js/bootstrap.min.js
# Bootstrap/js/bootstrap.min.js.map
# DataTables/jquery.dataTables.min.css
# DataTables/jquery.dataTables.min.js
# aaaaa.png
# admin/css/autocomplete.css
# admin/css/base.css
# admin/css/changelists.css
# admin/css/dashboard.css
# admin/css/fonts.css
# admin/css/forms.css
# admin/css/login.css
# admin/css/responsive.css
# admin/css/responsive_rtl.css
# admin/css/rtl.css
# admin/css/vendor/select2/LICENSE-SELECT2.md
# admin/css/vendor/select2/select2.css
# admin/css/vendor/select2/select2.min.css
# admin/css/widgets.css
# admin/fonts/LICENSE.txt
# admin/fonts/README.txt
# admin/fonts/Roboto-Bold-webfont.woff
# admin/fonts/Roboto-Light-webfont.woff
# admin/fonts/Roboto-Regular-webfont.woff
# admin/img/LICENSE
# admin/img/README.txt
# admin/img/calendar-icons.svg
# admin/img/gis/move_vertex_off.svg
# admin/js/vendor/select2/i18n/sv.js
# admin/js/vendor/select2/i18n/th.js
# admin/js/vendor/select2/i18n/tr.js
# admin/js/vendor/select2/i18n/uk.js
# admin/js/vendor/select2/i18n/vi.js
# admin/js/vendor/select2/i18n/zh-CN.js
# admin/js/vendor/select2/i18n/zh-TW.js
# admin/js/vendor/select2/select2.full.js
# admin/js/vendor/select2/select2.full.min.js
# admin/js/vendor/xregexp/LICENSE.txt
# admin/js/vendor/xregexp/xregexp.js
# admin/js/vendor/xregexp/xregexp.min.js
# azure_app/voices/sample-20191026-1612.wav
# azure_app/voices/sample-20191026-1614.wav
# azure_app/voices/sample-20191026-1615.wav
# azure_app/voices/sample-20191026-1616.wav
# azure_app/voices/sample-20191027-0430.wav
# basic_app/pictures/logo.png
# basic_app/pictures/logomini.png
# basic_app/pictures/microsoft.png
# css/override.css
# icons/LICENSE.txt
# icons/css/all.css
# icons/css/all.min.css
# icons/css/brands.css
# icons/css/brands.min.css
# icons/css/fontawesome.css
# icons/css/fontawesome.min.css
# icons/css/regular.css
# icons/css/regular.min.css
# icons/css/solid.css
# icons/css/solid.min.css
# icons/css/svg-with-js.css
# icons/css/svg-with-js.min.css
# icons/css/v4-shims.css
# icons/css/v4-shims.min.css
# icons/js/all.js
# icons/js/all.min.js
# icons/js/brands.js
# icons/js/brands.min.js
# icons/js/fontawesome.js
# icons/js/fontawesome.min.js
# icons/js/regular.js
# icons/js/regular.min.js
# icons/js/solid.js
# icons/js/solid.min.js
# icons/js/v4-shims.js
# icons/js/v4-shims.min.js
# icons/less/_animated.less
# icons/less/_bordered-pulled.less
# icons/less/_core.less
# icons/less/_fixed-width.less
# icons/less/_icons.less
# icons/less/_larger.less
# icons/less/_list.less
# icons/less/_mixins.less
# icons/less/_rotated-flipped.less
# icons/less/_screen-reader.less
# icons/less/_shims.less
# icons/less/_stacked.less
# icons/less/_variables.less
# icons/less/brands.less
# icons/less/fontawesome.less
# icons/less/regular.less
# icons/less/solid.less
# icons/less/v4-shims.less
# icons/metadata/categories.yml
# icons/metadata/icons.json
# icons/metadata/icons.yml
# icons/metadata/shims.json
# icons/metadata/shims.yml
# icons/metadata/sponsors.yml
# icons/scss/_animated.scss
# icons/scss/_bordered-pulled.scss
# icons/scss/_core.scss
# icons/scss/_fixed-width.scss
# icons/scss/_icons.scss
# icons/scss/_larger.scss
# icons/scss/_list.scss
# icons/scss/_mixins.scss
# icons/scss/_rotated-flipped.scss
# icons/scss/_screen-reader.scss
# icons/scss/_shims.scss
# icons/scss/_stacked.scss
# icons/scss/_variables.scss
# icons/scss/brands.scss
# icons/scss/fontawesome.scss
# icons/scss/regular.scss
# icons/scss/solid.scss
# icons/scss/v4-shims.scss
# icons/sprites/brands.svg
# icons/sprites/regular.svg
# icons/sprites/solid.svg
# icons/svgs/brands/500px.svg
# icons/svgs/brands/accessible-icon.svg
# icons/svgs/brands/accusoft.svg
# icons/svgs/brands/acquisitions-incorporated.svg
# icons/svgs/brands/adn.svg
# icons/svgs/brands/adobe.svg
# icons/svgs/solid/yin-yang.svg
# icons/webfonts/fa-brands-400.eot
# icons/webfonts/fa-brands-400.svg
# icons/webfonts/fa-brands-400.ttf
# icons/webfonts/fa-brands-400.woff
# icons/webfonts/fa-brands-400.woff2
# icons/webfonts/fa-regular-400.eot
# icons/webfonts/fa-regular-400.svg
# icons/webfonts/fa-regular-400.ttf
# icons/webfonts/fa-regular-400.woff
# icons/webfonts/fa-regular-400.woff2
# icons/webfonts/fa-solid-900.eot
# icons/webfonts/fa-solid-900.svg
# icons/webfonts/fa-solid-900.ttf
# icons/webfonts/fa-solid-900.woff
# icons/webfonts/fa-solid-900.woff2
# jQuery/jquery-3.4.1.js
# jQuery/jquery-ui.js
# jQuery/popper.min.js
# js/contentswitch.js
# js/navigation.js
# logo.png
# logomini.png
# microsoft.png
# myblockblob.csv
# pictures/children.jpg
# pictures/images.jpg
# radar_test_1.png
# radar_test_37.png
# radar_test_38.png
# radar_test_39.png
# radar_test_40.png
# radar_test_41.png
# radar_test_42.png
# radar_test_43.png
# radar_test_44.png
# radar_test_45.png
# radar_test_46.png
# radar_test_47.png
# radar_test_48.png
# radar_test_50.png
# radar_test_51.png
# rest_framework/css/bootstrap-theme.min.css
# rest_framework/css/bootstrap-tweaks.css
# rest_framework/css/bootstrap.min.css
# rest_framework/css/default.css
# rest_framework/css/font-awesome-4.0.3.css
# rest_framework/css/prettify.css
# rest_framework/docs/css/base.css
# rest_framework/docs/css/highlight.css
# rest_framework/docs/css/jquery.json-view.min.css
# rest_framework/docs/img/favicon.ico
# rest_framework/docs/img/grid.png
# rest_framework/docs/js/api.js
# rest_framework/docs/js/highlight.pack.js
# rest_framework/docs/js/jquery.json-view.min.js
# rest_framework/fonts/fontawesome-webfont.eot
# rest_framework/fonts/fontawesome-webfont.svg
# rest_framework/fonts/fontawesome-webfont.ttf
# rest_framework/fonts/fontawesome-webfont.woff
# rest_framework/fonts/glyphicons-halflings-regular.eot
# rest_framework/fonts/glyphicons-halflings-regular.svg
# rest_framework/fonts/glyphicons-halflings-regular.ttf
# rest_framework/fonts/glyphicons-halflings-regular.woff
# rest_framework/fonts/glyphicons-halflings-regular.woff2
# rest_framework/img/glyphicons-halflings-white.png
# rest_framework/img/glyphicons-halflings.png
# rest_framework/img/grid.png
# rest_framework/js/ajax-form.js
# rest_framework/js/bootstrap.min.js
# rest_framework/js/coreapi-0.1.1.js
# rest_framework/js/csrf.js
# rest_framework/js/default.js
# rest_framework/js/jquery-3.4.1.min.js
# rest_framework/js/prettify-min.js
# statistics_app/pictures/radar_test_1.png
# statistics_app/pictures/radar_test_1aaa.png
# statistics_app/pictures/radar_test_2.png
# statistics_app/pictures/radar_test_3.png
# statistics_app/pictures/radar_test_37.png
# statistics_app/pictures/radar_test_38.png
# statistics_app/pictures/radar_test_39.png
# statistics_app/pictures/radar_test_4.png
# statistics_app/pictures/radar_test_40.png
# statistics_app/pictures/radar_test_41.png
# statistics_app/pictures/radar_test_42.png
# statistics_app/pictures/radar_test_43.png
# statistics_app/pictures/radar_test_44.png
# statistics_app/pictures/radar_test_45.png
# statistics_app/pictures/radar_test_46.png
# statistics_app/pictures/radar_test_47.png
# statistics_app/pictures/radar_test_48.png
# statistics_app/pictures/radar_test_5.png
# statistics_app/pictures/radar_test_50.png
# statistics_app/pictures/radar_test_51.png
# statistics_app/pictures/radar_test_52.png
# statistics_app/pictures/radar_test_53.png
# statistics_app/pictures/radar_test_54.png
# statistics_app/pictures/radar_test_55.png
# statistics_app/pictures/radar_test_56.png
# statistics_app/pictures/radar_test_57.png
# statistics_app/pictures/radar_test_58.png
# statistics_app/pictures/radar_test_59.png
# statistics_app/pictures/radar_test_60.png
# statistics_app/pictures/radar_test_61.png
# statistics_app/pictures/radar_test_62.png
# statistics_app/pictures/radar_test_63.png
# statistics_app/pictures/radar_test_64.png
# statistics_app/pictures/radar_test_65.png
# statistics_app/pictures/radar_test_66.png
# statistics_app/pictures/radar_test_67.png
# statistics_app/pictures/radar_test_68.png
# statistics_app/pictures/radar_test_69.png
# statistics_app/pictures/radar_test_7.png
# statistics_app/pictures/radar_test_70.png
# statistics_app/pictures/radar_test_71.png
# statistics_app/pictures/radar_test_72.png
# statistics_app/pictures/radar_test_73.png
# statistics_app/pictures/radar_test_74.png
# statistics_app/pictures/radar_test_75.png
# statistics_app/pictures/radar_test_76.png
# statistics_app/pictures/radar_test_77.png
# statistics_app/pictures/radar_test_78.png
# statistics_app/pictures/radar_test_79.png
# statistics_app/pictures/radar_test_8.png
# statistics_app/pictures/radar_test_80.png
# statistics_app/pictures/radar_test_81.png
# statistics_app/pictures/radar_test_82.png
# statistics_app/pictures/radar_test_9.png

# %%
# Download the CSV file From Azure storage
block_blob_service.get_blob_to_path('mycontainer', 'myblockblob.csv', 'out-test.csv')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/_auth.py in _add_authorization_header(self, request, string_to_sign)
#      68         try:
# ---> 69             signature = _sign_string(self.account_key, string_to_sign)
#      70             auth_string = 'SharedKey ' + self.account_name + ':' + signature
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/_common_conversion.py in _sign_string(key, string_to_sign, key_is_base64)
#      90     if key_is_base64:
# ---> 91         key = _decode_base64_to_bytes(key)
#      92     else:
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/_common_conversion.py in _decode_base64_to_bytes(data)
#      80         data = data.encode('utf-8')
# ---> 81     return base64.b64decode(data)
#      82
#
# ~/anaconda3/lib/python3.7/base64.py in b64decode(s, altchars, validate)
#      86         raise binascii.Error('Non-base64 digit found')
# ---> 87     return binascii.a2b_base64(s)
#      88
#
# Error: Invalid base64-encoded string: number of data characters (5) cannot be 1 more than a multiple of 4
#
# During handling of the above exception, another exception occurred:
#
# AzureSigningError                         Traceback (most recent call last)
# <ipython-input-3-98c79b5c36b9> in <module>
#       3
#       4 block_blob_service = BlockBlobService(account_name='<myaccount>', account_key='mykey')
# ----> 5 block_blob_service.create_container('mycontainer')
#       6
#       7 #Upload the CSV file to Azure cloud
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/blob/baseblobservice.py in create_container(self, container_name, metadata, public_access, fail_on_exist, timeout)
#     691         if not fail_on_exist:
#     692             try:
# --> 693                 self._perform_request(request, expected_errors=[_CONTAINER_ALREADY_EXISTS_ERROR_CODE])
#     694                 return True
#     695             except AzureHttpError as ex:
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/storageclient.py in _perform_request(self, request, parser, parser_args, operation_context, expected_errors)
#     400                                 client_request_id_prefix,
#     401                                 exception_str_in_one_line)
# --> 402                     raise ex
#     403
#     404                 logger.info("%s Operation failed: checking if the operation should be retried. "
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/storageclient.py in _perform_request(self, request, parser, parser_args, operation_context, expected_errors)
#     372                 except AzureException as ex:
#     373                     retry_context.exception = ex
# --> 374                     raise ex
#     375                 except Exception as ex:
#     376                     retry_context.exception = ex
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/storageclient.py in _perform_request(self, request, parser, parser_args, operation_context, expected_errors)
#     312                     try:
#     313                         # request can be signed individually
# --> 314                         self.authentication.sign_request(request)
#     315                     except AttributeError:
#     316                         # session can also be signed
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/_auth.py in sign_request(self, request)
#      90             self._get_canonicalized_resource_query(request)
#      91
# ---> 92         self._add_authorization_header(request, string_to_sign)
#      93         logger.debug("String_to_sign=%s", string_to_sign)
#      94
#
# ~/anaconda3/lib/python3.7/site-packages/azure/storage/common/_auth.py in _add_authorization_header(self, request, string_to_sign)
#      73             # Wrap any error that occurred as signing error
#      74             # Doing so will clarify/locate the source of problem
# ---> 75             raise _wrap_exception(ex, AzureSigningError)
#      76
#      77     def sign_request(self, request):
#
# AzureSigningError: Invalid base64-encoded string: number of data characters (5) cannot be 1 more than a multiple of 4

# %%
# !pip install azure-storage-blob
# Out:
# Collecting azure-storage-blob
#   Downloading https://files.pythonhosted.org/packages/3e/84/610f379b46d7d3c2d48eadeed6a12b6d46a43100fea70534f5992d0ac996/azure_storage_blob-2.1.0-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 1.4MB/s ta 0:00:01
# Collecting azure-storage-common~=2.1 (from azure-storage-blob)
#   Downloading https://files.pythonhosted.org/packages/6b/a0/6794b318ce0118d1a4053bdf0149a60807407db9b710354f2b203c2f5975/azure_storage_common-2.1.0-py2.py3-none-any.whl (47kB)
#     100% |████████████████████████████████| 51kB 14.8MB/s ta 0:00:01
# Requirement already satisfied: azure-common>=1.1.5 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from azure-storage-blob) (1.1.23)
# Requirement already satisfied: requests in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from azure-storage-common~=2.1->azure-storage-blob) (2.21.0)
# Requirement already satisfied: python-dateutil in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from azure-storage-common~=2.1->azure-storage-blob) (2.8.0)
# Requirement already satisfied: cryptography in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from azure-storage-common~=2.1->azure-storage-blob) (2.6.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from requests->azure-storage-common~=2.1->azure-storage-blob) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from requests->azure-storage-common~=2.1->azure-storage-blob) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from requests->azure-storage-common~=2.1->azure-storage-blob) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from requests->azure-storage-common~=2.1->azure-storage-blob) (2019.3.9)
# Requirement already satisfied: six>=1.5 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from python-dateutil->azure-storage-common~=2.1->azure-storage-blob) (1.12.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from cryptography->azure-storage-common~=2.1->azure-storage-blob) (1.12.2)
# Requirement already satisfied: asn1crypto>=0.21.0 in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from cryptography->azure-storage-common~=2.1->azure-storage-blob) (0.24.0)
# Requirement already satisfied: pycparser in /Users/emmertgergo/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography->azure-storage-common~=2.1->azure-storage-blob) (2.19)
# Installing collected packages: azure-storage-common, azure-storage-blob
# Successfully installed azure-storage-blob-2.1.0 azure-storage-common-2.1.0
